# %%
# Шаг 4_7_1

# Тема: Воспроизведение шифровальной машины Энигмы

# Господин программист, добро пожаловать в Блетчли-парк!

# Мы рады, что вы присоединились к нам в эти неспокойные времена, когда нацисты всё чаще совершают налёты на Лондон.
# Совсем скоро вы сможете встретиться с Аланом, но пока необходимо немного поработать с теми материалами, что наши друзья из Польши доставили с риском для жизни.

# Наша задача — взломать Энигму.
# Но чтобы что-то сломать, сперва необходимо это воспроизвести.
# Вашей задачей и будет **воспроизведение шифровальной машины по полученным спецификациям**.

# А пока ваша помощница заваривает чай, можете почитать заметку, которая на пальцах описывает основные принципы работы Энигмы — https://habr.com/ru/post/217331/

# %%
# Шаг 4_7_2

# Задание: rotor(symbol, n, reverse=False)

# Напишите функцию `rotor(symbol, n, reverse=False)`, реализующую шифрование одним ротором Энигмы.

# Функция принимает:
#   • `symbol` — символ, поступающий для шифрования.
#   • `n` — номер ротора (0, 1, 2, 3).
#   • `reverse` — признак обратного направления (по умолчанию False — прямое).

# Возвращает строку с зашифрованным символом.

# Алгоритм:
#   • Если `n = 0` — "не шифрованный ротор" — возвращает тот же символ.
#   • Для `n = 1, 2, 3` — использует таблицу соответствия из спецификации:
#         Rotor I:  E K M F L G D Q V Z N T O W Y H X U S P A I B R C J
#         Rotor II: A J D K S I R U X B L H W T M C Q G Z N P Y F V O E
#         Rotor III: B D F H J L C P R T X V Z N Y E I W G A K M U S Q O

#   • При `reverse=True` — используется обратное соответствие (например, если 'A' → 'E', то 'E' → 'A').

# Примеры:
#   rotor('A', 0) → 'A'
#   rotor('A', 1) → 'E'
#   rotor('E', 1, reverse=True) → 'A'

# Примечание:
#   • В этой задаче не нужно ничего считывать и ничего выводить на печать.
#   • Требуется только реализовать функцию.

RDICT = {1: ('AELTPHQXRU', 'BKNW', 'CMOY', 'DFG', 'IV', 'JZ', 'S'),
         2: ('FIXVYOMW', 'CDKLHUP', 'ESZ', 'BJ', 'GR', 'NT', 'A', 'Q'),
         3: ('ABDHPEJT', 'CFLVMZOYQIRWUKXSG', 'N'),
         4: ('AEPLIYWCOXMRFZBSTGJQNH', 'DV', 'KU'),
         5: ('AVOLDRWFIUQ', 'BZKSMNHYC', 'EGTJPX'),
         6: ('AJQDVLEOZWIYTS', 'CGMNHFUX', 'BPRK'),
         7: ('ANOUPFRIMBZTLWKSVEGCJYDHXQ'),
         8: ('AFLSETWUNDHOZVICQ', 'BKJ', 'GXY', 'MPR'),
         'beta': ('ALBEVFCYODJWUGNMQTZSKPR', 'HIX'),
         'gamma': ('AFNIRLBSQWVXGUZDKMTPCOYJHE'),
         }

RDICT_0 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def rotor (symbol, n, reverse = False):
    text = []
    for aa in symbol:
        if n == 0:
            if aa.upper() in RDICT_0:
                text.append(aa.upper())
        else:
            tuple_dict = list(RDICT[n])
            # print(tuple_dict)
            aa = aa.upper()
            k = len(tuple_dict)
            # print(k)
            for i in range(k):
                if aa in tuple_dict[i]:
                    # print(tuple_dict[i])
                    idx = tuple_dict[i].index(aa)
                    step = 1
                    if reverse:
                        step = -1
                    if idx + step >= len(tuple_dict[i]):
                        idx_n = idx + step - len(tuple_dict[i])
                    elif idx + step < 0:
                        idx_n = idx + step + len(tuple_dict[i])
                    else:
                        idx_n = idx + step
                    bb = tuple_dict[i][idx_n]
                    # print(bb)
                    text.append(bb)
    total_text = ''.join(text)
    return total_text


rotor('SOME ENCRYPTED TEXT FOR EXAMPLE', 3, True)
# Out:
# 'XZVPPNGIOHJPBJPKJCZIPKTVHFP'

# %%
# Шаг 4_7_3

# Задание: reflector(symbol, n)

# Напишите функцию `reflector(symbol, n)`, реализующую отражатель Энигмы.

# Функция принимает:
#   • `symbol` — символ, поступающий для шифрования.
#   • `n` — номер отражателя (0 или 1).

# Возвращает строку с зашифрованным символом.

# Алгоритм:
#   • Если `n = 0` — "без шифрования" — возвращает тот же символ.
#   • Если `n = 1` — использует таблицу соответствия из спецификации:
#         Reflector B: Y R U H Q S L D P X N G O K M I E B F Z C W V J A T

# Примеры:
#   reflector('A', 0) → 'A'
#   reflector('A', 1) → 'T'
#   reflector('T', 1) → 'A' (обратимость)

# Примечание:
#   • В этой задаче не нужно ничего считывать и ничего выводить на печать.
#   • Требуется только реализовать функцию.

REFLECTORS = {0: 'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
              1: 'YRUHQSLDPXNGOKMIEBFZCWVJAT',
              2: 'FVPJIAOYEDRZXWGCTKUQSBNMHL',
              3: 'ENKQAUYWJICOPBLMDXZVFTHRGS',
              4: 'RDOBJNTKVEHMLFCWZAXGYIPSUQ',
              }

def reflector(symbol, n):
    text = []
    list_dict = list(REFLECTORS[n])
    list_0 = list(REFLECTORS[0])
    # print(list_dict)
    for aa in symbol:
        aa = aa.upper()
        if aa in list_dict:
            k = list_0.index(aa)
            d = list_dict[k]
            text.append(d)
            # print(aa, k, d)
    total_text = ''.join(text)
    return total_text

reflector(' SOME ENCRYPTED TEXT FOR EXAMPLE', 1)
# Out:
# 'FMOQQKUBAIZQHZQJZSMBQJYOIGQ'

# %%
# Шаг 4_7_4

# Тема: Сборка статической Энигмы

# Отлично, сэр!

# Кажется, вы готовы собрать свою первую статическую Энигму.
# Посмотрите описание процесса тут — https://www.codesandciphers.org.uk/enigma/example1.htm

# Напомним:
#   • У нас есть N роторов разных видов (не обязательно, но как правило — 3) и отражатель.
#   • Сигнал проходит через роторы последовательно — внутри каждого происходит замена символа согласно спецификации ротора.
#   • Далее сигнал передаётся с одного ротора на другой.
#   • Сигнал доходит до отражателя, на котором так же шифруется.
#   • Сигнал начинает обратное путешествие по роторам, шифруясь на каждом из них (с обратным смещением), а также, если роторы не совмещены, то шифруется шифром Цезаря при переходе от одного ротора к другому.

# ⚠️ ВАЖНО!
# Если роторы не совмещены, то шифр Цезаря применяется:
#   • прямой при движении "туда"
#   • обратный при движении "обратно"

# Запутанно? На самом деле не так страшно.

# Давайте рассмотрим несколько примеров.

'''
Пример 1
Используем: Ротор 1, Отражатель "B".

Смещение: отсутствует

Процесс шифрования:

Берём символ "A", передаём в Ротор 1 в прямом направлении, получаем "E"
Отражаем символ "E" в отражателе B, получаем "Q"
Передаём в Ротор 1 в обратном направлении "Q", получаем "H"
Результат: A>E>Q>H

На выходе из шифровальной машины видим символ "H"



Пример 2
Используем: Ротор 3, Ротор 2, Ротор 1, Отражатель "B".

Смещение: отсутствует

Процесс шифрования:

Берём символ "A", передаём в Ротор 3 в прямом направлении, получаем "B"
Передаём "B" в Ротор 2 в прямом направлении, получаем "J"
Передаём "J" в Ротор 1 в прямом направлении, получаем "Z"
Отражаем "Z" в отражателе, получаем "T"
Передаём "T" в Ротор 1 в обратном направлении, получаем "L"
Передаём "L" в Ротор 2 в обратном направлении, получаем "K"
Передаём "K" в Ротор 3 в обратном направлении, получаем "U"
Результат: A>B>J>Z>T>L>K>U

На выходе из шифровальной машины видим символ "U"
'''

# %%
# Шаг 4_7_5

# Задание: enigma(text, ref, rot1, rot2, rot3)

# Напишите функцию `enigma(text, ref, rot1, rot2, rot3)`, реализующую простейшую версию Энигмы.

# Функция принимает:
#   • `text` — исходный текст (без пробелов и знаков препинания).
#   • `ref` — номер отражателя (0 или 1).
#   • `rot1`, `rot2`, `rot3` — номера роторов (0, 1, 2, 3).

# Алгоритм:
#   • Сигнал проходит через роторы справа налево (rot3 → rot2 → rot1), затем в отражатель, и обратно (rot1 → rot2 → rot3).
#   • Смещения и движение роторов отсутствуют — статическая машина.
#   • Используйте таблицы из предыдущих задач для роторов и отражателей.

# Функция возвращает зашифрованный текст.

# Примеры:
#   enigma('A', 1, 1, 0, 0) → 'H'
#   enigma('A', 1, 1, 2, 3) → 'U'
#   enigma('U', 1, 1, 2, 3) → 'A'

# Примечание:
#   • В этой задаче не нужно ничего считывать и ничего выводить на печать.
#   • Требуется только реализовать функцию.

RDICT = {1: ('AELTPHQXRU', 'BKNW', 'CMOY', 'DFG', 'IV', 'JZ', 'S'),
         2: ('FIXVYOMW', 'CDKLHUP', 'ESZ', 'BJ', 'GR', 'NT', 'A', 'Q'),
         3: ('ABDHPEJT', 'CFLVMZOYQIRWUKXSG', 'N'),
         4: ('AEPLIYWCOXMRFZBSTGJQNH', 'DV', 'KU'),
         5: ('AVOLDRWFIUQ', 'BZKSMNHYC', 'EGTJPX'),
         6: ('AJQDVLEOZWIYTS', 'CGMNHFUX', 'BPRK'),
         7: ('ANOUPFRIMBZTLWKSVEGCJYDHXQ'),
         8: ('AFLSETWUNDHOZVICQ', 'BKJ', 'GXY', 'MPR'),
         'beta': ('ALBEVFCYODJWUGNMQTZSKPR', 'HIX'),
         'gamma': ('AFNIRLBSQWVXGUZDKMTPCOYJHE'),
         }

RDICT_0 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def rotor (symbol, n, reverse = False):
    text = []
    for aa in symbol:
        if n == 0:
            if aa.upper() in RDICT_0:
                text.append(aa.upper())
        else:
            tuple_dict = list(RDICT[n])
            # print(tuple_dict)
            aa = aa.upper()
            k = len(tuple_dict)
            # print(k)
            for i in range(k):
                if aa in tuple_dict[i]:
                    # print(tuple_dict[i])
                    idx = tuple_dict[i].index(aa)
                    step = 1
                    if reverse:
                        step = -1
                    if idx + step >= len(tuple_dict[i]):
                        idx_n = idx + step - len(tuple_dict[i])
                    elif idx + step < 0:
                        idx_n = idx + step + len(tuple_dict[i])
                    else:
                        idx_n = idx + step
                    bb = tuple_dict[i][idx_n]
                    # print(bb)
                    text.append(bb)
    total_text = ''.join(text)
    return total_text


# rotor('SOME ENCRYPTED TEXT FOR EXAMPLE', 3, True)

REFLECTORS = {0: 'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
              1: 'YRUHQSLDPXNGOKMIEBFZCWVJAT',
              2: 'FVPJIAOYEDRZXWGCTKUQSBNMHL',
              3: 'ENKQAUYWJICOPBLMDXZVFTHRGS',
              4: 'RDOBJNTKVEHMLFCWZAXGYIPSUQ',
              }

def reflector(symbol, n):
    text = []
    list_dict = list(REFLECTORS[n])
    list_0 = list(REFLECTORS[0])
    # print(list_dict)
    for aa in symbol:
        aa = aa.upper()
        if aa in list_dict:
            k = list_0.index(aa)
            d = list_dict[k]
            text.append(d)
            # print(aa, k, d)
    total_text = ''.join(text)
    return total_text

# reflector(' SOME ENCRYPTED TEXT FOR EXAMPLE', 1)

def enigma(text, ref, rot1, rot2, rot3):
    text = rotor(text, rot3, False)
    # print(text)
    text = rotor(text, rot2, False)
    # print(text)
    text = rotor(text, rot1, False)
    # print(text)
    text = reflector(text, ref)
    # print(text)
    text = rotor(text, rot1, True)
    # print(text)
    text = rotor(text, rot2, True)
    # print(text)
    text = rotor(text, rot3, True)
    # print(text)
    return text

enigma('SOMEENCRIPTEDTEXT', 1, 1, 2, 3)
# Out:
# 'LDRBBKJMWGFBOFBYF'

# %%
# Шаг 4_7_6

# Тема: Энигма с поворотом роторов (смещением)

# В предыдущем шаге мы реализовали статическую Энигму — без смещения роторов.
# Теперь добавим **смещение** — ключевое свойство настоящей машины.

# Суть:
#   • Роторы можно повернуть вокруг своей оси — это задаёт их начальное положение.
#   • Смещение влияет на шифрование: символ, попавший в ротор, сначала "сдвигается" на величину смещения, затем шифруется по таблице, и потом "возвращается" обратно.

# Фактически, это эквивалентно применению шифра Цезаря перед входом в ротор и после выхода из него.

# Правила:
#   1. При переходе сигнала с клавиатуры на самый правый ротор — применяется смещение этого ротора.
#   2. При переходе сигнала от одного ротора к другому — применяется смещение следующего ротора.
#   3. При прохождении сигнала через отражатель — смещение не применяется.
#   4. При переходе сигнала от отражателя к роторам — применяется смещение ротора, но в обратном направлении (т.е. "обратное смещение").

# Пример: если ротор смещён на +2, то:
#   • В прямом направлении: символ 'A' → сдвигаем на +2 → 'C', шифруем → результат.
#   • В обратном направлении: символ 'C' → сдвигаем на -2 → 'A', шифруем → результат.

# Это позволяет использовать один и тот же алгоритм шифрования, просто меняя смещение.

# Важно: положительное смещение по дороге "туда" превращается в отрицательное смещение по дороге "обратно".

# Примеры:
#   • Пример 3: Ротор 3 смещён на +2 → символ 'A' → +2 → 'C' → шифруется → ... → на выходе получаем 'C'.
#   • Пример 4: Ротор 3 смещён на +2 → символ 'A' → +2 → 'C' → шифруется → ... → на выходе получаем 'D'.

# Запутанно? На самом деле — нет!
# Давайте рассмотрим несколько примеров.


# Пример: если Ротор 3 смещён на +2, то:
#   • В прямом направлении: символ 'A' → сдвигаем на +2 → 'C', затем шифруем по таблице ротора.
#   • В обратном направлении: символ 'C' → сдвигаем на -2 → 'A', затем шифруем по таблице ротора.

# Это эквивалентно применению шифра Цезаря перед входом в ротор и после выхода из него.

# Процесс шифрования для примера с роторами 3, 2, 1 и отражателем "B":

#   • Берём символ "A", смещаем его на +1 (смещение ротора 3), получаем "B".
#   • Передаём "B" в Ротор 3 в прямом направлении, получаем "D".
#   • Смещаем символ "D" на +1 (смещение ротора 2), получаем "E".
#   • Передаём "E" в Ротор 2 в прямом направлении, получаем "S".
#   • Смещаем символ "S" на +1 (смещение ротора 1), получаем "T".
#   • Передаём "T" в Ротор 1 в прямом направлении, получаем "R".
#   • Отражаем "R" в отражателе, получаем "Q".
#   • Смещаем символ "Q" на -1 (обратное смещение ротора 1), получаем "P".
#   • Передаём "P" в Ротор 1 в обратном направлении, получаем "U".
#   • Смещаем символ "U" на -1 (обратное смещение ротора 2), получаем "T".
#   • Передаём "T" в Ротор 2 в обратном направлении, получаем "W".
#   • Смещаем символ "W" на -1 (обратное смещение ротора 3), получаем "V".
#   • Передаём "V" в Ротор 3 в обратном направлении, получаем "Q".

# Результат: A>B>D>E>S>T>R>Q>P>U>T>W>V>Q

# На выходе из шифровальной машины видим символ "Q".

# Важно: положительное смещение по дороге "туда" превращается в отрицательное смещение по дороге "обратно".

# %%
# Шаг 4_7_7

# Задание: enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3)

# Напишите функцию `enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3)`, реализующую Энигму с поворотом роторов.

# Функция принимает:
#   • `text` — исходный текст (без пробелов и знаков препинания).
#   • `ref` — номер отражателя (0 или 1).
#   • `rot1`, `rot2`, `rot3` — номера роторов (0, 1, 2, 3).
#   • `shift1`, `shift2`, `shift3` — сдвиги роторов (целые числа от -25 до 25).

# Алгоритм:
#   • Сигнал проходит через роторы справа налево (rot3 → rot2 → rot1), затем в отражатель, и обратно (rot1 → rot2 → rot3).
#   • При входе в ротор — применяется **смещение этого ротора**.
#   • При выходе из ротора — применяется **обратное смещение** (т.е. минус смещения).
#   • Используйте таблицы из предыдущих задач для роторов и отражателей.

# Функция возвращает зашифрованный текст.

# Примеры:
#   enigma('A', 1, 1, 0, 0, 0, 3, 2) → 'C'
#   enigma('A', 1, 1, 0, 2, 0, 3, 2) → 'D'
#   enigma('A', 1, 1, 0, 2, 0, 3, 1) → 'Y'

# Примечание:
#   • В этой задаче не нужно ничего считывать и ничего выводить на печать.
#   • Требуется только реализовать функцию.

RDICT = {1: ('AELTPHQXRU', 'BKNW', 'CMOY', 'DFG', 'IV', 'JZ', 'S'),
         2: ('FIXVYOMW', 'CDKLHUP', 'ESZ', 'BJ', 'GR', 'NT', 'A', 'Q'),
         3: ('ABDHPEJT', 'CFLVMZOYQIRWUKXSG', 'N'),
         4: ('AEPLIYWCOXMRFZBSTGJQNH', 'DV', 'KU'),
         5: ('AVOLDRWFIUQ', 'BZKSMNHYC', 'EGTJPX'),
         6: ('AJQDVLEOZWIYTS', 'CGMNHFUX', 'BPRK'),
         7: ('ANOUPFRIMBZTLWKSVEGCJYDHXQ'),
         8: ('AFLSETWUNDHOZVICQ', 'BKJ', 'GXY', 'MPR'),
         'beta': ('ALBEVFCYODJWUGNMQTZSKPR', 'HIX'),
         'gamma': ('AFNIRLBSQWVXGUZDKMTPCOYJHE'),
         }

RDICT_0 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def rotor (symbol, n, reverse = False):
    text = []
    for aa in symbol:
        if n == 0:
            if aa.upper() in RDICT_0:
                text.append(aa.upper())
        else:
            tuple_dict = list(RDICT[n])
            # print(tuple_dict)
            aa = aa.upper()
            k = len(tuple_dict)
            # print(k)
            for i in range(k):
                if aa in tuple_dict[i]:
                    # print(tuple_dict[i])
                    idx = tuple_dict[i].index(aa)
                    step = 1
                    if reverse:
                        step = -1
                    if idx + step >= len(tuple_dict[i]):
                        idx_n = idx + step - len(tuple_dict[i])
                    elif idx + step < 0:
                        idx_n = idx + step + len(tuple_dict[i])
                    else:
                        idx_n = idx + step
                    bb = tuple_dict[i][idx_n]
                    # print(bb)
                    text.append(bb)
    total_text = ''.join(text)
    return total_text


# rotor('SOME ENCRYPTED TEXT FOR EXAMPLE', 3, True)

REFLECTORS = {0: 'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
              1: 'YRUHQSLDPXNGOKMIEBFZCWVJAT',
              2: 'FVPJIAOYEDRZXWGCTKUQSBNMHL',
              3: 'ENKQAUYWJICOPBLMDXZVFTHRGS',
              4: 'RDOBJNTKVEHMLFCWZAXGYIPSUQ',
              }

def reflector(symbol, n):
    text = []
    list_dict = list(REFLECTORS[n])
    list_0 = list(REFLECTORS[0])
    # print(list_dict)
    for aa in symbol:
        aa = aa.upper()
        if aa in list_dict:
            k = list_0.index(aa)
            d = list_dict[k]
            text.append(d)
            # print(aa, k, d)
    total_text = ''.join(text)
    return total_text

# reflector(' SOME ENCRYPTED TEXT FOR EXAMPLE', 1)

def caesar(text, key, alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'):
    key = int(key)
    M1 = str(alphabet)
    len_alphabet = len(alphabet)
    a = list(text.upper())
    while key < 0:
        key += len_alphabet
    while key >= (len_alphabet - 1):
        key -= len_alphabet
    c = []
    for i in a:
        if i == ',' or i == '.' or i == '?' or i == '!' or i == ' ' or i == ':' or i == ';' or i == '\'' or i == '"':
            continue
        if i in M1 and (M1.index(i) + key) < len_alphabet:
            k = M1.index(i) + key
        elif i in M1:
            k = M1.index(i) + key - len_alphabet
        p = M1[k]
        c.append(p)
    d = ''.join(c)
    return d

# caesar("АБВГД", 2, "ABCDEFGHIJKLMNOPQRSTUVWXYZАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ")

def enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3):
    text = caesar(text, shift3)
    # print(text)
    text = rotor(text, rot3, False)
    # print(text)
    text = caesar(text, shift2-shift3)
    # print(text)
    text = rotor(text, rot2, False)
    # print(text)
    text = caesar(text, shift1-shift2)
    # print(text)
    text = rotor(text, rot1, False)
    # print(text)
    text = caesar(text, -shift1)
    # print(text)
    text = reflector(text, ref)
    # print(text)
    text = caesar(text, shift1)
    # print(text)
    text = rotor(text, rot1, True)
    # print(text)
    text = caesar(text, shift2-shift1)
    # print(text)
    text = rotor(text, rot2, True)
    # print(text)
    text = caesar(text, shift3-shift2)
    # print(text)
    text = rotor(text, rot3, True)
    # print(text)
    text = caesar(text, -shift3)
    # print(text)
    return text

enigma('AYIQQLXZMFHQUHQCH', 1, 1, -1, 2, 2, 3, -1)
# Out:
# 'SOMEENCRIPTEDTEXT'

# %%
# Шаг 4_7_8

# Тема: Энигма с вращением роторов (динамическая версия)

# Сэр, поздравляю — ваша Энигма уже почти настоящая!
# Почему "почти"? Потому что **роторы поворачиваются** прямо в процессе работы машины!

# Механизм:
#   1. После нажатия клавиши на клавиатуре и до передачи её на правый ротор — он **сдвигается на 1 позицию**.
#      • Т.е. если в начале процесса шифрования положение ротора было 0, то первый символ шифруется со смещением +1, второй — со смещением +2, и т.д.

#   2. У каждого ротора есть специальный механизм, позволяющий повернуть соседний (находящийся левее) ротор при определённых условиях.
#      • Условием является достижение ротором определённого смещения, указанного в таблице:

# | Ротор    | at R | при смещении |
# |----------|------|-------------|
# | Rotor I  | at R | 17          |
# | Rotor II | at F | 5           |
# | Rotor III| at W | 22          |
# | Rotor IV | at K | 10          |
# | Rotor V  | at A | 0           |
# | Rotors VI, VII and VIII | at A and at N | 0 или 13 |

#   • Если правый ротор — 3, со смещением 0 в начальный момент, то при каждом нажатии клавиши его собственное смещение увеличивается на 1.
#   • Как только мы нажмём 22-й раз любую клавишу (т.е. подадим любой символ на кодирование), то на 1 увеличится смещение правого ротора И на 1 увеличится смещение центрального ротора (Ротор 3 повернёт соседа на 1).

# Примечание:
#   • Если любой ротор в процессе движения попадает на позицию предшествующую той, которая повернёт соседа, то на следующий шаг он повернётся ещё раз и повернёт соседа.

# Пример:
#   Все роторы — II.
#   Положение всех роторов +3
#   → II (+3), II (+3), II (+3)
#   Вводим 1 символ. Правый Ротор поворачивается на 1:
#   → II (+3), II (+3), II (+4)
#   Следующий ввод переведёт правый ротор в позицию, из которой он поворачивает на 1 соседа — центральный ротор.
#   → II (+3), II (+4), II (+5)
#   Центральный Ротор попал на позицию предшествующую поворотной. Следовательно он получает "право второго хода" — при следующем вводе он повернётся сам, и повернёт соседа (левый ротор) + по обычному правилу повернётся правый ротор.
#   → II (+4), II (+5), II (+6)
#   Дальше будет поворачиваться только правый Ротор до тех пор, пока снова не выйдет на позицию, позволяющую повернуть центральный.

# Это сложный, но очень красивый механизм — основа настоящей Энигмы.

# %%
# Шаг 4_7_9

# Этот шаг я не осили (только первые 2 теста верны)

# Задание: enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3)

# Напишите функцию `enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3)`, реализующую Энигму с поворотом и движением роторов.

# Функция принимает:
#   • `text` — исходный текст (без пробелов и знаков препинания).
#   • `ref` — номер отражателя (0 или 1).
#   • `rot1`, `rot2`, `rot3` — номера роторов (0, 1, 2, 3).
#   • `shift1`, `shift2`, `shift3` — начальные сдвиги роторов (целые числа от -25 до 25).

# Алгоритм:
#   • Сигнал проходит через роторы справа налево (rot3 → rot2 → rot1), затем в отражатель, и обратно (rot1 → rot2 → rot3).
#   • При входе в ротор — применяется **смещение этого ротора**.
#   • При выходе из ротора — применяется **обратное смещение** (т.е. минус смещения).
#   • После каждого символа правый ротор поворачивается на 1 позицию (смещение увеличивается на 1).
#   • В определённых ситуациях роторы сдвигают соседей слева от себя.

# Функция возвращает зашифрованный текст.

'''
Sample Input 1:

enigma('AAAAAAA', 1, 1, 0, 2, 0, 3, 0)
Sample Output 1:

BDZGOWC
Sample Input 2:

enigma('BDZGOWC', 1, 1, 0, 2, 0, 3, 0)
Sample Output 2:

AAAAAAA
Sample Input 3:

enigma('AAAAAAA', 1, 2, 3, 2, 3, 2, 3)
Sample Output 3:

BGDMBTZ
Sample Input 4:

enigma('AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA AAAAA', 1, 2, 3, 2, 3, 2, 3)
Sample Output 4:

BGDMBTZUONCIZMORCPNVLGOVLMURTNZNDROPETXLPLYCMIBICXITUCM
Sample Input 5:

enigma('AAAAA AAAAA', 1, 1, 0, 2, 0, 2, 0)
Sample Output 5:

SMGJHIUWUF
Sample Input 6:

enigma('AAAAA AAAAA', 1, 1, 0, 2, 0, 1, 0)
Sample Output 6:

ZEMUOFUVNB
'''

# Примечание:
#   • В этой задаче не нужно ничего считывать и ничего выводить на печать.
#   • Требуется только реализовать функцию.

RDICT = {1: ('AELTPHQXRU', 'BKNW', 'CMOY', 'DFG', 'IV', 'JZ', 'S'),
         2: ('FIXVYOMW', 'CDKLHUP', 'ESZ', 'BJ', 'GR', 'NT', 'A', 'Q'),
         3: ('ABDHPEJT', 'CFLVMZOYQIRWUKXSG', 'N'),
         4: ('AEPLIYWCOXMRFZBSTGJQNH', 'DV', 'KU'),
         5: ('AVOLDRWFIUQ', 'BZKSMNHYC', 'EGTJPX'),
         6: ('AJQDVLEOZWIYTS', 'CGMNHFUX', 'BPRK'),
         7: ('ANOUPFRIMBZTLWKSVEGCJYDHXQ'),
         8: ('AFLSETWUNDHOZVICQ', 'BKJ', 'GXY', 'MPR'),
         'beta': ('ALBEVFCYODJWUGNMQTZSKPR', 'HIX'),
         'gamma': ('AFNIRLBSQWVXGUZDKMTPCOYJHE'),
         }

RDICT_0 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def rotor (symbol, n, reverse = False):
    text = []
    for aa in symbol:
        if n == 0:
            if aa.upper() in RDICT_0:
                text.append(aa.upper())
        else:
            tuple_dict = list(RDICT[n])
            # print(tuple_dict)
            aa = aa.upper()
            k = len(tuple_dict)
            # print(k)
            for i in range(k):
                if aa in tuple_dict[i]:
                    # print(tuple_dict[i])
                    idx = tuple_dict[i].index(aa)
                    step = 1
                    if reverse:
                        step = -1
                    if idx + step >= len(tuple_dict[i]):
                        idx_n = idx + step - len(tuple_dict[i])
                    elif idx + step < 0:
                        idx_n = idx + step + len(tuple_dict[i])
                    else:
                        idx_n = idx + step
                    bb = tuple_dict[i][idx_n]
                    # print(bb)
                    text.append(bb)
    total_text = ''.join(text)
    return total_text


# rotor('SOME ENCRYPTED TEXT FOR EXAMPLE', 3, True)

REFLECTORS = {0: 'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
              1: 'YRUHQSLDPXNGOKMIEBFZCWVJAT',
              2: 'FVPJIAOYEDRZXWGCTKUQSBNMHL',
              3: 'ENKQAUYWJICOPBLMDXZVFTHRGS',
              4: 'RDOBJNTKVEHMLFCWZAXGYIPSUQ',
              }

def reflector(symbol, n):
    text = []
    list_dict = list(REFLECTORS[n])
    list_0 = list(REFLECTORS[0])
    # print(list_dict)
    for aa in symbol:
        aa = aa.upper()
        if aa in list_dict:
            k = list_0.index(aa)
            d = list_dict[k]
            text.append(d)
            # print(aa, k, d)
    total_text = ''.join(text)
    return total_text

# reflector(' SOME ENCRYPTED TEXT FOR EXAMPLE', 1)

def caesar(text, key, alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'):
    key = int(key)
    M1 = str(alphabet)
    len_alphabet = len(alphabet)
    a = list(text.upper())
    while key < 0:
        key += len_alphabet
    while key >= (len_alphabet - 1):
        key -= len_alphabet
    c = []
    for i in a:
        if i == ',' or i == '.' or i == '?' or i == '!' or i == ' ' or i == ':' or i == ';' or i == '\'' or i == '"':
            continue
        if i in M1 and (M1.index(i) + key) < len_alphabet:
            k = M1.index(i) + key
        elif i in M1:
            k = M1.index(i) + key - len_alphabet
        p = M1[k]
        c.append(p)
    d = ''.join(c)
    return d

# caesar("АБВГД", 2, "ABCDEFGHIJKLMNOPQRSTUVWXYZАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ")

def enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3):
    tot_text = []
    prom_text = text.split(' ')
    text = ''.join(prom_text)
    # print(prom_text)
    # print(text)
    for ii in range(len(text)):
        shift3 += 1

        if (rot2 == 1 and shift2 == 16) or (rot2 == 2 and shift2 == 4) or (rot2 == 3 and shift2 == 21) or (rot2 == 4 and shift2 == 9):
            shift2 += 1
            shift1 += 1
        if (rot2 == 5 and shift2 == 25) or (rot2 == 6 and (shift2 == 25 or shift2 == 12)) or (rot2 == 7 and (shift2 == 25 or shift2 == 12)) or (rot2 == 8 and (shift2 == 25 or shift2 == 12)):
            shift1 += 1
        if shift2 == 26:
            shift2 += 1
            shift2 = 0
        if shift1 == 26:
            shift1 = 0

        if shift3 == 26:
            shift3 = 0
        if (rot3 == 1 and shift3 == 17) or (rot3 == 2 and shift3 == 5) or (rot3 == 3 and shift3 == 22) or (rot3 == 4 and shift3 == 10):
            shift2 += 1
        if (rot3 == 5 and shift3 == 0) or (rot3 == 6 and (shift3 == 0 or shift3 == 13)) or (rot3 == 7 and (shift3 == 0 or shift3 == 13)) or (rot3 == 8 and (shift3 == 0 or shift3 == 13)):
            shift2 += 1

        if shift2 == 26:
            shift2 += 1
            shift2 = 0
        if shift1 == 26:
            shift1 = 0


        pp = text[ii]

        pp = caesar(pp, shift3)
        # print(pp)
        pp = rotor(pp, rot3, False)
        # print(pp)
        pp = caesar(pp, -shift3)

        pp = caesar(pp, shift2)
        # print(pp)
        pp = rotor(pp, rot2, False)
        # print(pp)
        pp = caesar(pp, -shift2)

        pp = caesar(pp, shift1)
        # print(pp)
        pp = rotor(pp, rot1, False)
        # print(pp)
        pp = caesar(pp, -shift1)
        # print(pp)

        pp = reflector(pp, ref)
        # print(pp)

        pp = caesar(pp, shift1)
        # print(pp)
        pp = rotor(pp, rot1, True)
        # print(pp)
        pp = caesar(pp, -shift1)

        pp = caesar(pp, shift2)
        # print(pp)
        pp = rotor(pp, rot2, True)
        # print(pp)
        pp = caesar(pp, -shift2)

        pp = caesar(pp, shift3)
        # print(pp)
        pp = rotor(pp, rot3, True)
        # print(pp)
        pp = caesar(pp, -shift3)
        # print(pp)

        tot_text.append(pp)
    sum_text = ''.join(tot_text)
    return sum_text

enigma('AAAAA AAAAA', 1, 1, 0, 2, 0, 1, 0)
# Out:
# 'ZEMUOFUVNB'

# %%
# Шаг 4_7_10

# Тема урока: Шифровальная машина "Энигма" и принцип работы её коммутационной панели (Steckerbrett)

# Основные понятия:
# - Коммутационная панель (Steckerbrett): панель с разъёмами для подключения проводов, позволяющая менять соответствие букв до и после шифрования роторами.
# - Попарное соединение: оператор соединяет две буквы проводом, создавая пару. Это означает, что при вводе одной буквы из пары на выходе получится другая, и наоборот.
# - Замена ДО шифрования: если буква A соединена с C, то при нажатии A на клавиатуре в роторы поступит сигнал от C.
# - Замена ПОСЛЕ шифрования: если роторы зашифровали сигнал в Q, а Q соединена с D, то на выходе будет D.

# Пример работы:
# Предположим, используется Роторы 1, 2, 3 и отражатель типа "B", без начального смещения.
# Без коммутации: при вводе 'A' на выходе получаем 'B'.

# Скоммутируем пару: 'A' и 'C'
# Тогда:
#   - ПЕРЕД шифрованием: ввод 'A' -> заменяется на 'C' -> в роторы поступает 'C'
#   - Роторы шифруют 'C' -> получаем, например, 'Q'
#   - ПОСЛЕ шифрования: 'Q' не скоммутирована -> на выходе 'Q'

# Если бы мы скоммутировали ещё одну пару: 'Q' и 'D'
# Тогда:
#   - ПЕРЕД шифрованием: ввод 'A' -> заменяется на 'C' -> в роторы поступает 'C'
#   - Роторы шифруют 'C' -> получаем 'Q'
#   - ПОСЛЕ шифрования: 'Q' заменяется на 'D' -> на выходе 'D'

# Важно:
# - В латинском алфавите 26 символов, поэтому можно скоммутировать максимум 13 пар (все гнёзда заняты) или меньше (часть гнёзд свободны).
# - Если символ не скоммутирован, для него замена не производится.

# %%
# Шаг 4_7_11

# Задание №2. Коммутация.

# Шифровальная машина «Энигма» имела коммутационную панель, расположенную на лицевой стороне корпуса.
# Эта панель представляла собой 26 гнёзд (по одному для каждой буквы латинского алфавита), в которые оператор мог вставить до 13 проводов.
# Каждый провод соединял пару гнёзд — то есть две буквы.

# Такое соединение обеспечивало взаимную замену букв:
# если буквы A и C были соединены проводом, то при вводе A на выходе получалась C, и наоборот.
# Буквы, не задействованные ни в одном соединении, оставались без изменений.

# Важно:
# - Каждая буква может участвовать не более чем в одной паре.
# - Соединение осуществляется до и после прохождения сигнала через роторы и отражатель. То есть:
#     * Если нажимается буква A, и A скоммутирована с C, то в роторы поступает сигнал от C.
#     * После прохождения роторов и отражателя получаем, например, сигнал от Q.
#     * Если Q скоммутирована с D, то в итоге загорается лампочка D.

# Допустим, без коммутации и при фиксированных настройках роторов
# (rotor1 = 1, rotor2 = 2, rotor3 = 3, сдвиги = 0, отражатель = 1)
# при вводе символа 'A' получается 'B'.

# Требуется доработать функцию enigma(...), добавив поддержку параметра pairs,
# задающего коммутацию. Параметр pairs — строка, содержащая список пар вида "AB XY ZQ"
# (пары разделены пробелами, каждая пара — 2 символа).

# Если в pairs есть нарушения (повтор букв, некорректная длина и т.п.),
# функция должна вернуть строку:
# "Извините, невозможно произвести коммутацию"

# Гарантируется, что во входных данных используются только заглавные латинские буквы,
# и роторы/отражатель работают корректно и детерминированно
# (их реализация — за рамками текущего задания).

def bi_pairs(symbol, pairs = ""):

        if pairs == "":
            return symbol
        else:
            pary = list(pairs.upper())
            # print(pary)
            set_pary = set(pary)
            # print(set_pary)
            if len(set_pary) != len(pary):
                return ("Извините, невозможно произвести коммутацию")
            pary = ''.join(pary)
            # print(pary)
            pary = pary.split(' ')
            # print(pary)

            for k in range(len(pary)):
                if symbol in pary[k]:
                    # print(pary[k])
                    if symbol == pary[k][0]:
                        symbol = pary[k][1]
                    elif symbol == pary[k][1]:
                        symbol = pary[k][0]

        return(symbol)


bi_pairs('B', 'AC qd')

# a = list(text.upper())
# Out:
# 'B'

# %%
RDICT = {1: ('AELTPHQXRU', 'BKNW', 'CMOY', 'DFG', 'IV', 'JZ', 'S'),
         2: ('FIXVYOMW', 'CDKLHUP', 'ESZ', 'BJ', 'GR', 'NT', 'A', 'Q'),
         3: ('ABDHPEJT', 'CFLVMZOYQIRWUKXSG', 'N'),
         4: ('AEPLIYWCOXMRFZBSTGJQNH', 'DV', 'KU'),
         5: ('AVOLDRWFIUQ', 'BZKSMNHYC', 'EGTJPX'),
         6: ('AJQDVLEOZWIYTS', 'CGMNHFUX', 'BPRK'),
         7: ('ANOUPFRIMBZTLWKSVEGCJYDHXQ'),
         8: ('AFLSETWUNDHOZVICQ', 'BKJ', 'GXY', 'MPR'),
         'beta': ('ALBEVFCYODJWUGNMQTZSKPR', 'HIX'),
         'gamma': ('AFNIRLBSQWVXGUZDKMTPCOYJHE'),
         }

RDICT_0 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def rotor (symbol, n, reverse = False):
    text = []
    for aa in symbol:
        if n == 0:
            if aa.upper() in RDICT_0:
                text.append(aa.upper())
        else:
            tuple_dict = list(RDICT[n])
            # print(tuple_dict)
            aa = aa.upper()
            k = len(tuple_dict)
            # print(k)
            for i in range(k):
                if aa in tuple_dict[i]:
                    # print(tuple_dict[i])
                    idx = tuple_dict[i].index(aa)
                    step = 1
                    if reverse:
                        step = -1
                    if idx + step >= len(tuple_dict[i]):
                        idx_n = idx + step - len(tuple_dict[i])
                    elif idx + step < 0:
                        idx_n = idx + step + len(tuple_dict[i])
                    else:
                        idx_n = idx + step
                    bb = tuple_dict[i][idx_n]
                    # print(bb)
                    text.append(bb)
    total_text = ''.join(text)
    return total_text


# rotor('SOME ENCRYPTED TEXT FOR EXAMPLE', 3, True)

REFLECTORS = {0: 'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
              1: 'YRUHQSLDPXNGOKMIEBFZCWVJAT',
              2: 'FVPJIAOYEDRZXWGCTKUQSBNMHL',
              3: 'ENKQAUYWJICOPBLMDXZVFTHRGS',
              4: 'RDOBJNTKVEHMLFCWZAXGYIPSUQ',
              }

def reflector(symbol, n):
    text = []
    list_dict = list(REFLECTORS[n])
    list_0 = list(REFLECTORS[0])
    # print(list_dict)
    for aa in symbol:
        aa = aa.upper()
        if aa in list_dict:
            k = list_0.index(aa)
            d = list_dict[k]
            text.append(d)
            # print(aa, k, d)
    total_text = ''.join(text)
    return total_text

# reflector(' SOME ENCRYPTED TEXT FOR EXAMPLE', 1)

def caesar(text, key, alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'):
    key = int(key)
    M1 = str(alphabet)
    len_alphabet = len(alphabet)
    a = list(text.upper())
    while key < 0:
        key += len_alphabet
    while key >= (len_alphabet - 1):
        key -= len_alphabet
    c = []
    for i in a:
        if i == ',' or i == '.' or i == '?' or i == '!' or i == ' ' or i == ':' or i == ';' or i == '\'' or i == '"':
            continue
        if i in M1 and (M1.index(i) + key) < len_alphabet:
            k = M1.index(i) + key
        elif i in M1:
            k = M1.index(i) + key - len_alphabet
        p = M1[k]
        c.append(p)
    d = ''.join(c)
    return d

# caesar("АБВГД", 2, "ABCDEFGHIJKLMNOPQRSTUVWXYZАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ")


def bi_pairs(symbol, pairs = ""):

        if pairs == "":
            return symbol
        else:
            pary = list(pairs.upper())
            # print(pary)
            set_pary = set(pary)
            # print(set_pary)
            if len(set_pary) != len(pary):
                return ("Извините, невозможно произвести коммутацию")
            pary = ''.join(pary)
            # print(pary)
            pary = pary.split(' ')
            # print(pary)

            for k in range(len(pary)):
                if symbol in pary[k]:
                    # print(pary[k])
                    if symbol == pary[k][0]:
                        symbol = pary[k][1]
                    elif symbol == pary[k][1]:
                        symbol = pary[k][0]

        return(symbol)

# bi_pairs('A', 'AC qd za')

def enigma(text, ref, rot1, shift1, rot2, shift2, rot3, shift3, pairs=""):

    if pairs:
        pary = pairs.upper().split(' ')
        all_chars = []
        for p in pary:
            if len(p) != 2:
                return("Извините, невозможно произвести коммутацию")
            all_chars.extend(p)
        if len(all_chars) != len(set(all_chars)):
            return("Извините, невозможно произвести коммутацию")


    tot_text = []
    prom_text = text.split(' ')
    text = ''.join(prom_text)
    # print(prom_text)
    # print(text)
    for ii in range(len(text)):

        pp = text[ii]
        pp = bi_pairs(pp, pairs)


        # text[ii] = bi_pairs(text[ii], pairs)

        shift3 += 1

        if (rot2 == 1 and shift2 == 16) or (rot2 == 2 and shift2 == 4) or (rot2 == 3 and shift2 == 21) or (rot2 == 4 and shift2 == 9):
            shift2 += 1
            shift1 += 1
        if (rot2 == 5 and shift2 == 25) or (rot2 == 6 and (shift2 == 25 or shift2 == 12)) or (rot2 == 7 and (shift2 == 25 or shift2 == 12)) or (rot2 == 8 and (shift2 == 25 or shift2 == 12)):
            shift1 += 1
        if shift2 == 26:
            shift2 += 1
            shift2 = 0
        if shift1 == 26:
            shift1 = 0

        if shift3 == 26:
            shift3 = 0
        if (rot3 == 1 and shift3 == 17) or (rot3 == 2 and shift3 == 5) or (rot3 == 3 and shift3 == 22) or (rot3 == 4 and shift3 == 10):
            shift2 += 1
        if (rot3 == 5 and shift3 == 0) or (rot3 == 6 and (shift3 == 0 or shift3 == 13)) or (rot3 == 7 and (shift3 == 0 or shift3 == 13)) or (rot3 == 8 and (shift3 == 0 or shift3 == 13)):
            shift2 += 1

        if shift2 == 26:
            shift2 += 1
            shift2 = 0
        if shift1 == 26:
            shift1 = 0


        # pp = text[ii]

        pp = caesar(pp, shift3)
        # print(pp)
        pp = rotor(pp, rot3, False)
        # print(pp)
        pp = caesar(pp, -shift3)

        pp = caesar(pp, shift2)
        # print(pp)
        pp = rotor(pp, rot2, False)
        # print(pp)
        pp = caesar(pp, -shift2)

        pp = caesar(pp, shift1)
        # print(pp)
        pp = rotor(pp, rot1, False)
        # print(pp)
        pp = caesar(pp, -shift1)
        # print(pp)

        pp = reflector(pp, ref)
        # print(pp)

        pp = caesar(pp, shift1)
        # print(pp)
        pp = rotor(pp, rot1, True)
        # print(pp)
        pp = caesar(pp, -shift1)

        pp = caesar(pp, shift2)
        # print(pp)
        pp = rotor(pp, rot2, True)
        # print(pp)
        pp = caesar(pp, -shift2)

        pp = caesar(pp, shift3)
        # print(pp)
        pp = rotor(pp, rot3, True)
        # print(pp)
        pp = caesar(pp, -shift3)
        # print(pp)

        pp = bi_pairs(pp, pairs)

        tot_text.append(pp)
    sum_text = ''.join(tot_text)
    return sum_text


enigma('AAAAAAA', 1, 1, 0, 2, 0, 3, 0)
# Out:
# 'BDZGOWC'

# %%
# Шаг 4_7_12

# Сэр, это отличная новость — теперь у нас есть своя Энигма, и мы можем выпустить их столько, сколько нам необходимо!

# Как думаете, вы готовы помочь Алану с его Turing Bombe?
# Кстати, вы можете сравнить свою работу с другим интерактивным эмулятором — https://www.101computing.net/enigma-encoder/

# P.S. Мы получаем известия, что противник начинает производство новых энигм с усиленным шифрованием.
# Они имеют не 3, а 4 диска. Для вас ведь не составит труда сделать своё решение универсальным под старые и новые устройства?
